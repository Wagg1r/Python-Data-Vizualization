# %% [markdown]
# Part 0

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Part1

# %%
rand = np.random.random(1000)
np.shape(rand)
#np.std(rand)
np.mean(rand)
# Out:
# 0.5093424763233783

# %% [markdown]
# 2a. the shape is 1000, there are no nested arrays so it is just one number
# b.min = 0 max =1
# c standard deviation = 0.28938414722555933
# mean = 0.5126480988853998

# %%
plt.hist(rand)
# Out:
# (array([105., 101.,  92.,  83.,  95., 106.,  95., 110., 108., 105.]),
#  array([0.00108461, 0.10085688, 0.20062915, 0.30040142, 0.40017369,
#         0.49994596, 0.59971823, 0.6994905 , 0.79926277, 0.89903504,
#         0.99880731]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 3. It is relatively uniform it favors some numbers slightly but this is to be expected with a random number generator especially with a lower number of random inputs. if it was exactly even across all numbers it wouldn't be random. The bigger the number the more evenly it will be distributed.

# %% [markdown]
# 4. the plot changes randomly when it is being rerun. It flucuates between which numbers it favors which is good because when you take all of the different runs it should even out over time.

# %%
rand2 = np.random.normal(0,1,1000)
np.shape(rand2)
# Out:
# (1000,)

# %%
plt.hist(rand2)
# Out:
# (array([  2.,  11.,  66., 180., 304., 242., 133.,  50.,   8.,   4.]),
#  array([-3.53752119, -2.81078512, -2.08404906, -1.35731299, -0.63057692,
#          0.09615915,  0.82289521,  1.54963128,  2.27636735,  3.00310342,
#          3.72983949]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 2a. the shape is still 1000
# b.the max and min are varied it seems to be between min -5 and max 5 on most runs
# c mean 0 and std is 1
# 3. it favors the number 0 heavily
# 4. the plot changes slightly but still favors 0 heavily

# %%
rand3 = np.random.normal(1,0.2,1000000)
plt.hist(rand3, bins = 100)
# Out:
# (array([1.0000e+00, 5.0000e+00, 4.0000e+00, 1.0000e+01, 1.4000e+01,
#         1.5000e+01, 1.8000e+01, 2.6000e+01, 4.5000e+01, 4.8000e+01,
#         8.0000e+01, 1.0700e+02, 1.3500e+02, 1.9400e+02, 2.6600e+02,
#         3.6100e+02, 5.1500e+02, 5.5800e+02, 7.6100e+02, 1.0480e+03,
#         1.2980e+03, 1.6000e+03, 1.9890e+03, 2.4910e+03, 3.1070e+03,
#         3.8720e+03, 4.4970e+03, 5.5040e+03, 6.6370e+03, 7.8080e+03,
#         9.1490e+03, 1.0598e+04, 1.2084e+04, 1.3801e+04, 1.6031e+04,
#         1.7772e+04, 1.9552e+04, 2.1884e+04, 2.4092e+04, 2.5812e+04,
#         2.7735e+04, 2.9307e+04, 3.1522e+04, 3.3188e+04, 3.4278e+04,
#         3.5117e+04, 3.6354e+04, 3.6791e+04, 3.7063e+04, 3.6952e+04,
#         3.6154e+04, 3.5505e+04, 3.4413e+04, 3.3106e+04, 3.1765e+04,
#         3.0007e+04, 2.8325e+04, 2.6168e+04, 2.4018e+04, 2.2122e+04,
#         2.0175e+04, 1.7980e+04, 1.5974e+04, 1.4154e+04, 1.2673e+04,
#         1.1025e+04, 9.3890e+03, 8.0300e+03, 6.9110e+03, 5.6820e+03,
# ...

# %%
rand4 = np.random.random(1000)
plt.plot(rand4)
plt.ylim(0,10)
# Out:
# (0.0, 10.0)

# %%
rand5 = np.random.randint(0,5,1000)
plt.plot(rand5)
plt.ylim(0,10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# 3. 0 is the min, numbers up to 5 is the max, 1000 is the number of random number or in this case the x axis.

# %%
rand6 = np.random.randint(0,5,15)
plt.plot(rand6)
plt.ylim(0,10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# 5. it makes the x axis all number up to 15

# %%
rand7 = np.random.randint(0,5,[15,2])
plt.plot(rand7)
plt.ylim(0,10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# 5. it plots two different lines ontop of each other.

# %%
plt.plot(rand7[:,0])
plt.ylim(0,10)
# Out:
# (0.0, 10.0)

# %%
plt.plot(rand7[:,1])
plt.ylim(0,10)
# Out:
# (0.0, 10.0)

# %%
rand7 = np.random.randint(1,5,[15,3])
plt.plot(rand7)
plt.ylim(0,5)
# Out:
# (0.0, 5.0)

# %% [markdown]
# this plottin makes three lines on top of each other. It makes an array of size 15,3 the 0th element in the array gets the blue line, 1st elemnt gets the orange, and 2nd gets the green line.

# %%
rand8 = np.random.randint(1,5,[5,100])
plt.plot(rand8)
plt.ylim(0,5)
plt.savefig('lab3 rand graph')
